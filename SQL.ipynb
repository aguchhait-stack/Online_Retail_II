# %%
ATTACH 'online_retail.duckdb' as db;
USE db;

# %% [markdown]
# ## Bronze Layer

# %%
CREATE  OR REPLACE TABLE retail_raw as 
SELECT * 
FROM read_csv_auto('data.nosync/online_retail_II.csv');

# %%
SELECT count(*) from retail_raw;
DESCRIBE retail_raw;
# Out:
# column_name    column_type    null    key    default    extra
# -------------  -------------  ------  -----  ---------  -------
# Invoice        VARCHAR        YES
# StockCode      VARCHAR        YES
# Description    VARCHAR        YES
# Quantity       BIGINT         YES
# InvoiceDate    TIMESTAMP      YES
# Price          DOUBLE         YES
# Customer ID    DOUBLE         YES
# Country        VARCHAR        YES
